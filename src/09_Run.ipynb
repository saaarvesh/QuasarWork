# %%
#%run 01_Data_Preparation.ipynb
#%run 02_Model_GuassianProcess.ipynb
#%run 03_Model_RNN_BNN.ipynb
#%run 04_Train_RNN_BNN.ipynb
# %run 05_Mu_Reconstruction.ipynb
# %run 06_Test_Redshift_Dependence.ipynb
# %run 07_Recaliberate_DistanceModulus.ipynb
# %run 08_Estimate_omegaM_and_omegaL.ipynb
# Out:
# c:\Users\Sarvesh Purohit\anaconda3\lib\site-packages\sklearn\gaussian_process\_gpr.py:492: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   y_samples = rng.multivariate_normal(y_mean, y_cov, n_samples).T
# C:\Users\Sarvesh Purohit\AppData\Local\Temp\ipykernel_15844\631166607.py:5: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
# Kernel parameters before fit:
# 1**2 + 1**2 * DotProduct(sigma_0=1) ** 0.1
# Kernel parameters after fit:
# 9.68**2 + 28**2 * DotProduct(sigma_0=0.00287) ** 0.1
# Log-likelihood: -3080.899
# Score = 0.4302415616162052
# c:\Users\Sarvesh Purohit\anaconda3\lib\site-packages\sklearn\gaussian_process\_gpr.py:492: RuntimeWarning: covariance is not symmetric positive-semidefinite.
#   y_samples = rng.multivariate_normal(y_mean, y_cov, n_samples).T
# ...
