# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
GRB = pd.read_csv('../out/quasar/gp/GRB_quasar.csv')

# %%
GRB.columns
# Out:
# Index(['Unnamed: 0', 'GRB', 'z', 'P_bolo', 'P_bolo_err', 'S_bolo',
#        'S_bolo_err', 'F_beam', 'F_beam_err', 'T_lag', 'T_lag_err', 'V',
#        'V_err', 'E_peak', 'E_peak_err_min', 'E_peak_err_max', 'T_RT',
#        'T_RT_err', 'mu', 'mu_err', 'dL', 'dL_err', 'L', 'L_err', 'E_iso',
#        'E_iso_err', 'E_gamma', 'E_gamma_err', 'E_peak_err', 'T_lag_i',
#        'T_lag_i_err', 'T_RT_i', 'T_RT_i_err', 'V_i', 'V_i_err', 'E_peak_i',
#        'E_peak_i_err', 'E_peak_i_err_min', 'E_peak_i_err_max', '_T_lag_i',
#        '_T_lag_i_err', '_V_i', '_V_i_err', '_E_peak_i', '_E_peak_i_err',
#        '_E_peak_i_err_min', '_E_peak_i_err_max', '_T_RT_i', '_T_RT_i_err',
#        'log_T_lag_i', 'log_T_lag_i_err', 'log_V_i', 'log_V_i_err',
#        'log_E_peak_i', 'log_E_peak_i_err', 'log_E_peak_i_err_min',
#        'log_E_peak_i_err_max', 'log_T_RT_i', 'log_T_RT_i_err', 'log_L',
#        'log_L_err', 'log_E_iso', 'log_E_iso_err', 'log_E_gamma',
#        'log_E_gamma_err'],
# ...

# %%
# plt.plot(z, dL, 'b-', label='Prediction',)
plt.errorbar(GRB['z'], GRB['dL'],yerr=GRB['dL_err'], fmt='.',color='r')
plt.xlabel('GRB redshift(z)')
plt.ylabel('DL')
#plt.title('The reconstruction of distance moduli from '+dataset+' data using Gaussian process')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
GPR = pd.read_csv('../out/quasar/gp/GRB_quasar.csv')
DNN = pd.read_csv('../out/quasar/lstm/GRB_quasar.csv')

# %%
plt.plot(GRB['z'], DNN['dL_err']/GPR['dL_err'])
plt.xlabel('GRB redshift(z)')
plt.ylabel('DL error ratio')
#plt.title('The reconstruction of distance moduli from '+dataset+' data using Gaussian process')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
